# %% [markdown]
# ## Cargar datos con la funcion read_csv

# %%
import pandas as pd
import os
import numpy as np
os.getcwd()
# Out:
# 'C:\\Users\\USER\\OneDrive\\Documentos\\GitHub\\python-ml-course\\notebooks_propios'

# %%
data = pd.read_csv(r"..\datasets\titanic\titanic3.csv")

# %% [markdown]
# En el caso de trabajar con windows se le debe agregar la letra "r" antes de colocar la ruta, de lo contrario da un error, puede que este relacionado a las ultimas actualizaciones que le han hecho a python.

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
pd.read_csv(filepath = r"..\datasets\chopsticks\chopstick-effectiveness.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25664\3362559439.py in <module>
# ----> 1 pd.read_csv(filepath = r"..\datasets\chopsticks\chopstick-effectiveness.csv")
#
# C:\ProgramData\anaconda3\envs\Curso_Juan_Gabriel\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'filepath'
